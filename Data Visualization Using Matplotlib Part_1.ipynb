# %%
# Content



# IMPORTING THE SCRIPTING LAYER PYPLOT OF MATPLOTLIB LIBRARY, 
#WHICH IS LIGHTER THAN THE ARTIST LAYER
# And importing numpy to generate 10000 random numbers

import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
x.mean()
x.std()

# To create histogram
plt.hist(x, bins=100)

plt.hist(x, bins=1000) # For finer bins
plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='left')
#plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='center')
#plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='right')

# To save in the current working directory, 
#we need to run the plot [any additional fetures and savefig() command together]
# By default png image would be saved
plt.hist(x, bins=1000) # For finer bins
plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='left')

plt.savefig('Histogram1')


# To save a figure, select picture & right click and save image as png.
# We can also copy image by using right click

# To check working directory
# %pwd


plt.hist(x, bins=1000) # For finer bins
plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='left')
plt.savefig("D:\Learning\Learn Python git hub\Histogram")

# IF we want to see figure in separate window & Play aroud with options

#Start by opening the Spyder preferences.
#Mac users can go to python -> Preferences... in the menubar
#Linux/Windows users can go to Tools -> Preferences
#In the Preferences window, click on IPython console on the left side of the window, then on the Graphics tab.
#Under Graphics backend, select Automatic [Earlier it was inline] for the backend.
#Restart Spyder.


# More innformation in the plot
plt.hist(x, bins=1000) # For finer bins
plt.title('Normal Distribution with $\mu=0, \sigma=1$', loc='center')   
# X axis label
plt.xlabel('Random Numbers')
# Y axis label
plt.ylabel('Frequency')
# Adding text at location (0, 50)
plt.text(0, 50, 'Mode')
# Defining range of axes ([xmin, xmax, ymin, ymax])
plt.axis([-3, 3, 0, 80])



# Difference between plt.show() and plt.draw()
# https://stackoverflow.com/questions/23141452/difference-between-plt-draw-and-plt-show-in-matplotlib

x = np.random.randn(10000)
plt.hist(x, bins=100)
plt.draw()
plt.show()
